# %%
# importing libraries
import numpy as np 
import pandas as pd 
import requests
from bs4 import BeautifulSoup

# %%
movies_df = pd.read_csv('movies.csv')
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ## 1.What is the shape of "movies.csv"

# %%
movies_df.shape
# Out:
# (9742, 3)

# %%
ratings_df = pd.read_csv('ratings.csv')
ratings_df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# ## 2.What is the shape of "ratings.csv"

# %%
ratings_df.shape
# Out:
# (100836, 4)

# %% [markdown]
# ## 3.What is the shape of "ratings.csv"

# %%
ratings_df['userId'].nunique()
# Out:
# 610

# %% [markdown]
# ## 4. Which movie has recieved maximum number of user ratings

# %%
movie_rating_df = pd.merge(movies_df,ratings_df,how='inner',on='movieId')

# %%
movie_rating_df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
grouped_df = movie_rating_df.groupby('title')

# %%
grouped_df['rating'].count().idxmax()
# Out:
# 'Forrest Gump (1994)'

# %% [markdown]
# ## 5. Select all the correct tags submitted by users to "Matrix, The (1999)" movie

# %%
tags_df = pd.read_csv('tags.csv')
tags_df
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
movie_ratings_df= pd.merge(movie_rating_df,tags_df,how='inner',on='movieId')
movie_ratings_df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId_x  rating  timestamp_x  userId_y    tag  timestamp_y
# 0         1     4.0    964982703       336  pixar   1139045764
# 1         1     4.0    964982703       474  pixar   1137206825
# 2         1     4.0    964982703       567    fun   1525286013
# 3         5     4.0    847434962       336  pixar   1139045764
# 4         5     4.0    847434962       474  pixar   1137206825

# %%
movie_ratings_df[movie_ratings_df["title"]=="Matrix, The (1999)"]['tag'].value_counts()
# Out:
# martial arts          278
# sci-fi                278
# alternate universe    278
# philosophy            278
# post apocalyptic      278
# Name: tag, dtype: int64

# %% [markdown]
# ## 6.What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"

# %%
movie_ratings_df[movie_ratings_df["title"]=="Terminator 2: Judgment Day (1991)"]['rating'].mean()
# Out:
# 3.970982142857143

# %% [markdown]
# ## 7.How does the data distribution of user ratings for "Fight Club (1999)" movie looks like

# %%
movie_ratings_df[movie_ratings_df["title"]=="Fight Club (1999)"]['rating'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# 🟢 IMPORTANT NOTE 1 🟢
# Now that you have a good enough understanding of the given data, apply the "Mandatory Operation" given below before solving any of the following questions.
#
# Mandatory Operations:
# 1. Group the user ratings based on movieId and apply aggregation operations like count and mean on ratings.
# 2. Apply inner join on dataframe created from movies.csv and the grouped df from step 1.
# 3. Filter only those movies which have more than 50 user ratings (i.e. > 50).
#
# Above steps will make sure that your data contains only those movies which has recieved more than 50 user ratings.

# %%
grouped_df = ratings_df.groupby('movieId')

# %%
grouped_df = grouped_df['rating'].agg(["count", "mean"]).reset_index()

# %%
grouped_df
# Out:
#       movieId  count      mean
# 0           1    215  3.920930
# 1           2    110  3.431818
# 2           3     52  3.259615
# 3           4      7  2.357143
# 4           5     49  3.071429
# ...       ...    ...       ...
# 9719   193581      1  4.000000
# 9720   193583      1  3.500000
# 9721   193585      1  3.500000
# 9722   193587      1  3.500000
# 9723   193609      1  4.000000
#
# [9724 rows x 3 columns]

# %%
count_df = pd.merge(movies_df,grouped_df,how='inner',on='movieId')
count_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  count      mean
# 0  Adventure|Animation|Children|Comedy|Fantasy    215  3.920930
# 1                   Adventure|Children|Fantasy    110  3.431818
# 2                               Comedy|Romance     52  3.259615
# 3                         Comedy|Drama|Romance      7  2.357143
# 4                                       Comedy     49  3.071429

# %%
final_count=count_df[count_df['count']>50]
final_count
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8287   106782   Wolf of Wall Street, The (2013)
# 8354   109374  Grand Budapest Hotel, The (2014)
# 8358   109487               Interstellar (2014)
# 8457   112852    Guardians of the Galaxy (2014)
# 8673   122904                   Deadpool (2016)
#
#                                            genres  count      mean
# 0     Adventure|Animation|Children|Comedy|Fantasy    215  3.920930
# 1                      Adventure|Children|Fantasy    110  3.431818
# 2                                  Comedy|Romance     52  3.259615
# 5                           Action|Crime|Thriller    102  3.946078
# ...

# %% [markdown]
# ## 8. Which movie is the most popular based on  average user ratings

# %%
final_count.loc[final_count['mean'].idxmax()]
# Out:
# movieId                                 318
# title      Shawshank Redemption, The (1994)
# genres                          Crime|Drama
# count                                   317
# mean                               4.429022
# Name: 277, dtype: object

# %% [markdown]
# ## 9. Select all the correct options which comes under top 5 popular movies based on number of user ratings.

# %%
final_count.sort_values(by='count',ascending=False)[:5]
# Out:
#       movieId                             title                       genres  \
# 314       356               Forrest Gump (1994)     Comedy|Drama|Romance|War
# 277       318  Shawshank Redemption, The (1994)                  Crime|Drama
# 257       296               Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 510       593  Silence of the Lambs, The (1991)        Crime|Horror|Thriller
# 1938     2571                Matrix, The (1999)       Action|Sci-Fi|Thriller
#
#       count      mean
# 314     329  4.164134
# 277     317  4.429022
# 257     307  4.197068
# 510     279  4.161290
# 1938    278  4.192446

# %% [markdown]
# ## 10.Which Sci-Fi movie is "third most popular" based on the number of user ratings?

# %%
final_count['genres'].value_counts()
# Out:
# Comedy                                    24
# Comedy|Romance                            21
# Drama                                     20
# Crime|Drama                               13
# Action|Adventure|Sci-Fi                   12
#                                           ..
# Action|Adventure|Western                   1
# Crime|Drama|Sci-Fi|Thriller                1
# Horror|Sci-Fi                              1
# Action|Adventure|Comedy|Fantasy|Horror     1
# Sci-Fi|IMAX                                1
# Name: genres, Length: 201, dtype: int64

# %%
scifi = final_count[final_count['genres'].str.contains('Sci-Fi')]

# %%
scifi.head()
# Out:
#      movieId                                      title  \
# 31        32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 133      160                               Congo (1995)
# 144      172                     Johnny Mnemonic (1995)
# 145      173                         Judge Dredd (1995)
# 176      208                          Waterworld (1995)
#
#                               genres  count      mean
# 31           Mystery|Sci-Fi|Thriller    177  3.983051
# 133  Action|Adventure|Mystery|Sci-Fi     57  2.877193
# 144           Action|Sci-Fi|Thriller     53  2.679245
# 145              Action|Crime|Sci-Fi     62  2.669355
# 176          Action|Adventure|Sci-Fi    115  2.913043

# %%
scifi.sort_values(by='count', ascending=False)[:3]
# Out:
#       movieId                                      title  \
# 1938     2571                         Matrix, The (1999)
# 224       260  Star Wars: Episode IV - A New Hope (1977)
# 418       480                       Jurassic Park (1993)
#
#                                 genres  count      mean
# 1938            Action|Sci-Fi|Thriller    278  4.192446
# 224            Action|Adventure|Sci-Fi    251  4.231076
# 418   Action|Adventure|Sci-Fi|Thriller    238  3.750000

# %% [markdown]
# 🟢 IMPORTANT NOTE 2 🟢
# You already have a subset of data containing only those movies which has recieved more than 50 user ratings.
#
# Using "links.csv", scrape the IMDB reviews of each movie with more than 50 user ratings. "README.md" file contains the required details.

# %%
links = pd.read_csv('links.csv')
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
final_df = pd.merge(final_count,links,how='inner',on=['movieId'])

# %%
def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {'Content-Type': 'text/html; charset=UTF-8', 
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                      'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(URL, headers=request_header)
    soup = BeautifulSoup(response.text)
    imdb_rating = soup.find('span', attrs={'class' : 'sc-bde20123-1 cMEQkK'})
    return imdb_rating.text if imdb_rating else np.nan

# %%
ratings = []
for i in list(final_df['imdbId']):
    ratings.append(scrapper(i))

# %%
final_df['ratings'] = ratings

# %%
final_df
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# ...

# %% [markdown]
# ## 11.Mention the movieId of the movie which has the highest IMDB rating.

# %%
final_df.sort_values(by='ratings',ascending=False)
# Out:
#      movieId                                              title  \
# 53       318                   Shawshank Redemption, The (1994)
# 117      858                              Godfather, The (1972)
# 146     1203                                12 Angry Men (1957)
# 364     7153  Lord of the Rings: The Return of the King, The...
# 156     1221                     Godfather: Part II, The (1974)
# ..       ...                                                ...
# 70       420                       Beverly Hills Cop III (1994)
# 28       153                              Batman Forever (1995)
# 73       435                                   Coneheads (1993)
# 30       160                                       Congo (1995)
# 260     2701                              Wild Wild West (1999)
#
#                               genres  count      mean  imdbId   tmdbId ratings
# 53                       Crime|Drama    317  4.429022  111161    278.0     9.3
# ...

# %% [markdown]
# ## 12.Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.

# %%
rating = final_df[final_df['genres'].str.contains('Sci-Fi')]
rating.head()
# Out:
#     movieId                                      title  \
# 12       32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 30      160                               Congo (1995)
# 35      172                     Johnny Mnemonic (1995)
# 36      173                         Judge Dredd (1995)
# 38      208                          Waterworld (1995)
#
#                              genres  count      mean  imdbId   tmdbId ratings
# 12          Mystery|Sci-Fi|Thriller    177  3.983051  114746     63.0     8.0
# 30  Action|Adventure|Mystery|Sci-Fi     57  2.877193  112715  10329.0     5.3
# 35           Action|Sci-Fi|Thriller     53  2.679245  113481   9886.0     5.6
# 36              Action|Crime|Sci-Fi     62  2.669355  113492   9482.0     5.6
# 38          Action|Adventure|Sci-Fi    115  2.913043  114898   9804.0     6.3

# %%
rating.sort_values(by='ratings',ascending=False)
# Out:
#      movieId                                              title  \
# 424    79132                                   Inception (2010)
# 248     2571                                 Matrix, The (1999)
# 433   109487                                Interstellar (2014)
# 140     1196  Star Wars: Episode V - The Empire Strikes Back...
# 44       260          Star Wars: Episode IV - A New Hope (1977)
# ..       ...                                                ...
# 36       173                                 Judge Dredd (1995)
# 35       172                             Johnny Mnemonic (1995)
# 73       435                                   Coneheads (1993)
# 30       160                                       Congo (1995)
# 260     2701                              Wild Wild West (1999)
#
#                                               genres  count      mean  \
# 424  Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX    143  4.066434
# ...
